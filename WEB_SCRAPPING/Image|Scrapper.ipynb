# %% [markdown]
# <a href="https://colab.research.google.com/github/officialkalpesh3170/DataScience/blob/main/WEB_SCRAPPING/Image%7CScrapper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
# !pip install selenium
sys.path.insert(0,'/usr/lib/chromium-browser/chromedriver')
from selenium import webdriver
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument('--headless') # this is must
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-dev-shm-usage')
import requests
from bs4 import BeautifulSoup
driver = webdriver.Chrome(options=chrome_options)
link='https://stock-pictures.netlify.app/'
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 49.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.3/486.3 kB 28.6 MB/s eta 0:00:00
# ...

# %%
link='https://stock-pictures.netlify.app/'
driver.get(link)

# %%
soup=BeautifulSoup(driver.page_source,'html.parser')

# %%
soup.find_all('div',class_='container')[0]
# Out:
# <div class="container"><div class="image-container"><img alt="src" class="source-img" src="https://cdn.pixabay.com/photo/2022/03/06/05/30/clouds-7050884__480.jpg"/></div><div class="tags"><span class="tag-color">Tags - Clouds, Sky, Atmosphere, Blue Sky</span></div><div class="likes-comments"><span>196 Likes</span><span>55 Comments </span></div></div>

# %%
data=[]

for i in soup.find_all('div',class_='container'):
   img=i.find('img').get('src')
   tag=list(set(i.find('div' ,class_='tags').text[7:].split(' ')))

   data.append([img ,tag])

# %%
import pandas as pd
df=pd.DataFrame(data,columns=['img','tag'])

# %%
df
# Out:
#                                                   img  \
# 0   https://cdn.pixabay.com/photo/2022/03/06/05/30...
# 1   https://cdn.pixabay.com/photo/2022/04/07/11/45...
# 2   https://cdn.pixabay.com/photo/2022/02/28/15/28...
# 3   https://cdn.pixabay.com/photo/2022/04/04/02/52...
# 4   https://cdn.pixabay.com/photo/2022/04/09/18/06...
# 5   https://cdn.pixabay.com/photo/2021/11/13/23/06...
# 6   https://cdn.pixabay.com/photo/2022/04/07/02/56...
# 7   https://cdn.pixabay.com/photo/2022/03/19/21/11...
# 8   https://cdn.pixabay.com/photo/2022/04/09/17/30...
# 9   https://cdn.pixabay.com/photo/2022/03/25/19/24...
# 10  https://cdn.pixabay.com/photo/2021/08/25/20/42...
# 11  https://cdn.pixabay.com/photo/2022/04/04/18/03...
# 12  https://cdn.pixabay.com/photo/2022/04/04/07/58...
# 13  https://cdn.pixabay.com/photo/2022/03/23/21/27...
# 14  https://cdn.pixabay.com/photo/2022/03/27/15/03...
# 15  https://cdn.pixabay.com/photo/2022/03/25/17/54...
# ...

# %%
df.to_csv('data.csv')

# %%
df=pd.read_csv('data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                                img  \
# 0           0  https://cdn.pixabay.com/photo/2022/03/06/05/30...
# 1           1  https://cdn.pixabay.com/photo/2022/04/07/11/45...
# 2           2  https://cdn.pixabay.com/photo/2022/02/28/15/28...
# 3           3  https://cdn.pixabay.com/photo/2022/04/04/02/52...
# 4           4  https://cdn.pixabay.com/photo/2022/04/09/18/06...
#
#                                                  tag
# 0  ['Sky', 'Blue', 'Sky,', 'Atmosphere,', 'Clouds,']
# 1           ['Bird,', 'Ornithology,', 'Hummingbird']
# 2   ['Rainfall,', 'Rainbow,', 'Subtropical', 'Sea,']
# 3  ['Sakura', 'Japan,', 'Blossoms,', 'Cherry', 'R...
# 4        ['Plant', 'Marguerite,', 'Cape', 'Flower,']

# %%
j=0
for i in df['img']:
  j+=1
  res= requests.get(i)
  fd=open(f'Img{j}.png','wb')
  fd.write(res.content)
fd.close()

# %%
res= requests.get(link)

# %%
fd=open('Img.png','wb')
fd.write(res.content)
fd.close()

# %%
# !ls
# Out:
# data.csv   Img15.png  Img20.png  Img26.png  Img31.png  Img37.png  Img42.png  Img48.png	Img9.png
# Img10.png  Img16.png  Img21.png  Img27.png  Img32.png  Img38.png  Img43.png  Img4.png	Img.png
# Img11.png  Img17.png  Img22.png  Img28.png  Img33.png  Img39.png  Img44.png  Img5.png	sample_data
# Img12.png  Img18.png  Img23.png  Img29.png  Img34.png  Img3.png   Img45.png  Img6.png
# Img13.png  Img19.png  Img24.png  Img2.png   Img35.png  Img40.png  Img46.png  Img7.png
# Img14.png  Img1.png   Img25.png  Img30.png  Img36.png  Img41.png  Img47.png  Img8.png
